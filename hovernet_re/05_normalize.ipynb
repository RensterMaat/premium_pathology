# %%
import openslide
import numpy as np
import matplotlib.pyplot as plt

img = openslide.OpenSlide('//home/rens/hpc/PREMIUM histopathology/data/isala/metastasis/PREM-IS-005_d5fa80a160 I10 HE1 - 2022-03-24 19.45.44.ndpi')
image = np.array(img.read_region((0,0), 3, img.level_dimensions[3]).convert('RGB'))

plt.figure(figsize=(12,12))
plt.imshow(image)
plt.show()

print(img.level_dimensions[0])
# Out:
# (122880, 96768)

# %%
from util import normalize_staining

# %%
img.level_dimensions
# Out:
# ((122880, 96768),
#  (61440, 48384),
#  (30720, 24192),
#  (15360, 12096),
#  (7680, 6048),
#  (3840, 3024),
#  (1920, 1512),
#  (960, 756),
#  (480, 378))

# %%
patch = np.array(img.read_region((70000,30000), 4, (256,256)).convert('RGB'))
normalized, _, _ = normalize_staining(patch)

fig, ax = plt.subplots(1,2, figsize=(12,6))
ax[0].imshow(patch)
ax[0].set_title('original')
ax[1].imshow(normalized)
ax[1].set_title('normalized')
fig.show()

# %%
plt.imshow(patch)

# %%
plt.imshow(patch)
